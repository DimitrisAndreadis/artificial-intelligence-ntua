# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Ανδρεάδης Δημήτρης 03119403
#
# Στοιχεία Μέλους 2: Ιωάννης Τζαχρήστας 03119090

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
path = '/content/drive/MyDrive/'
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
     movie_title = clean_text(getattr(row, 'movie_title'))    
     if movie_title != "UNK":            # Movie title is in all prolog clauses
          
          # Director
          director = clean_text(getattr(row, 'director_name'))
          if director != "UNK":
               literals.append("director('"+ movie_title +"','" + director + "')")               
            
          # Vote average (3 categories)
          vote_average = getattr(row, 'vote_average')
          if vote_average != "UNK":
               if float(vote_average) >= 7.5:
                    literals.append("vote_average('"+ movie_title +"','over7.5')")    
               elif float(vote_average) < 7.5 and float(vote_average) >= 5:
                    literals.append("vote_average('"+ movie_title +"','5-7.5')")        
               else: # vote_average < 3.0
                    literals.append("vote_average('"+ movie_title +"','under_5')") 

          # Movie popularity (3 categories)
          popularity = getattr(row, 'popularity')
          if popularity != "UNK":
               popularity = float(popularity)
               if popularity >= 100:
                    literals.append("popularity('"+ movie_title +"','high')")    
               elif popularity < 100 and popularity >= 20:
                    literals.append("popularity('"+ movie_title +"','medium')")  
               else: # popularity lower than 20
                    literals.append("popularity('"+ movie_title +"','low')")
   
        # Duration (3 categories)
          duration = getattr(row, 'duration')
          if duration != "UNK":
               if float(duration) > 120:
                    literals.append("duration('"+ movie_title +"','long')")    
               elif float(duration) < 120 and float(duration) >60:
                    literals.append("duration('"+ movie_title +"','medium')")  
               else:# duration < 60:
                    literals.append("duration('"+ movie_title +"','short')")           
        
        # Number of users that have voted the movie (3 categories)
          num_voted_users = getattr(row, 'num_voted_users')
          if num_voted_users != "UNK":
               if float(num_voted_users) >= 1000:
                    literals.append("num_voted_users('"+ movie_title +"','high')")         
               elif float(num_voted_users) > 200:
                    literals.append("num_voted_users('"+ movie_title +"','medium')")         
               else:
                    literals.append("num_voted_users('"+ movie_title +"','low')")  

        # Plot keywords
          for plot_keyword in clean_text(getattr(row, 'plot_keywords')).split("|"):
               literals.append("keyword('"+ movie_title +"','"+ plot_keyword +"')")
               if plot_keyword == "black and white":
                   color = "Black_and_White"
                   literals.append("color('"+ movie_title +"','" + color + "')")
        
        # Genre
          for genre in clean_text(getattr(row, 'genres')).split("|"):
               literals.append("genre('"+ movie_title +"','"+ genre +"')")

        # Actor
          for actor in [clean_text(getattr(row, 'actor_1_name')), clean_text(getattr(row, 'actor_2_name')), clean_text(getattr(row, 'actor_3_name'))]:
               literals.append("actor('"+ movie_title +"','"+ actor.replace("'",'"') +"')")

        # Language
          language = clean_text(getattr(row, 'language'))
          literals.append("language('"+ movie_title +"','"+ language +"')")

        # Production countries
          countries = getattr(row, 'production_countries')
          if countries != '[]':
               countries = countries[1:-1]
          for country in countries.split("'name': "):
               if country[0]=="'":
                    for country in country.split(","):
                         literals.append("country('"+ movie_title +"','"+ country[1:-2] +"')")
                         break

        # Production studios
          studios = getattr(row, 'production_companies')
          if studios != '[]':
               studios = studios[1:-1]
               for studio in studios.split("'name': "):
                    if studio[0]=="'":
                     for studio in studio.split(","):
                          literals.append("studio('"+ movie_title +"','"+ studio[1:-2] +"')")
                          break

        # Decade
          title_year = getattr(row, 'title_year')
          if title_year != "UNK":
               title_year = int(int(title_year)%100/10)*10
               if title_year == 0:
                    title_year = '00'
               else :
                    title_year = str(title_year)
                    literals.append("decade('"+ movie_title +"','" + title_year + "s')" )   



          


#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
 prolog.assertz(literal)
 print (literal +'.')
# Throughout the whole notebook we do not use consulting so "db.pl" file is empty
#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db.pl")
# Out:
# Streaming output truncated to the last 5000 lines.
# studio('Wyatt Earp','Paragon Entertainment Corp').
# studio('Wyatt Earp','Tig Production').
# studio('Wyatt Earp','Warner Bros').
# studio('X-Men Origins: Wolverine','Bad Hat Harry Production').
# studio('X-Men Origins: Wolverine','Big Screen Production').
# studio('X-Men Origins: Wolverine','Dune Entertainmen').
# studio('X-Men Origins: Wolverine','Ingenious Film Partner').
# studio('X-Men Origins: Wolverine','Marvel Enterprise').
# studio('X-Men Origins: Wolverine','Seed Production').
# studio('X-Men Origins: Wolverine','Twentieth Century Fox Film Corporatio').
# studio('X-Men','Bad Hat Harry Production').
# studio('X-Men','Genetics Production').
# studio('X-Men','Marvel Enterprise').
# studio('X-Men','Springwood Production').
# studio('X-Men','Twentieth Century Fox Film Corporatio').
# studio('X-Men: Apocalypse','Bad Hat Harry Production').
# studio('X-Men: Apocalypse','Kinberg Genr').
# studio('X-Men: Apocalypse','Marvel Entertainmen').
# studio('X-Men: Apocalypse','TSG Entertainmen').
# studio('X-Men: Apocalypse','Twentieth Century Fox Film Corporatio').
# studio('X-Men: Days of Future Past','Bad Hat Harry Production').
# studio('X-Men: Days of Future Past','Down Production').
# studio('X-Men: Days of Future Past','Marvel Entertainmen').
# studio('X-Men: Days of Future Past','Revolution Sun Studio').
# studio('X-Men: Days of Future Past','TSG Entertainmen').
# studio('X-Men: Days of Future Past','Twentieth Century Fox Film Corporatio').
# studio('X-Men: First Class','Bad Hat Harry Production').
# studio('X-Men: First Class','Big Screen Production').
# studio('X-Men: First Class','Dune Entertainmen').
# studio('X-Men: First Class','Dune Entertainment II').
# studio('X-Men: First Class','Ingenious Film Partner').
# studio('X-Men: First Class','Ingenious Medi').
# studio('X-Men: First Class','Marvel Entertainmen').
# studio('X-Men: First Class','Twentieth Century Fox Film Corporatio').
# studio('X-Men: The Last Stand','Bad Hat Harry Production').
# studio('X-Men: The Last Stand','Dune Entertainmen').
# studio('X-Men: The Last Stand','Ingenious Film Partner').
# studio('X-Men: The Last Stand','Major Studio Partner').
# studio('X-Men: The Last Stand','Marvel Enterprise').
# studio('X-Men: The Last Stand','Twentieth Century Fox Film Corporatio').
# studio('X-Men: The Last Stand','X3 Canada Production').
# studio('X-Men: The Last Stand','X3US Production').
# studio('X-Men: The Last Stand','XM3 Servic').
# studio('X-Men: The Last Stand','thinkfil').
# studio('X2','Bad Hat Harry Production').
# studio('X2','Marvel Enterprise').
# studio('X2','Twentieth Century Fox Film Corporatio').
# studio('X2','XF2 Canada Production').
# studio('X2','XM2 Production').
# studio('Y Tu Mamá También','Bésame Mucho Picture').
# studio('Y Tu Mamá También','Producciones Anhel').
# studio('Y Tu Mamá También','The Criterion Collectio').
# studio('Year One','Apatow Production').
# studio('Year One','Columbia Picture').
# studio('Year One','Ocean Picture').
# studio('Yeh Jawaani Hai Deewani','Dharma Production').
# studio('Yentl','Barwood Film').
# studio('Yentl','Ladbrok').
# studio('Yentl','United Artist').
# studio('Yes Man','Heyday film').
# studio('Yes Man','The Zanuck Compan').
# studio('Yes Man','Village Roadshow Picture').
# studio('Yes Man','Warner Bros').
# studio('Yes','Adventure Picture').
# studio('Yes','GreeneStreet Film').
# studio('Yes','Studio Fierber').
# studio('Yes','UK Film Counci').
# studio('Yoga Hosers','Abbolita Production').
# studio('Yoga Hosers','Destro Film').
# studio('Yoga Hosers','Invincible Pictures Corp').
# studio('Yogi Bear','De Line Picture').
# studio('Yogi Bear','Picnic Baske').
# studio('Yogi Bear','Rhythm and Hue').
# studio('Yogi Bear','Sunswept Entertainmen').
# studio('Yogi Bear','Warner Bros. Animatio').
# studio('You Again','Frontier Picture').
# studio('You Again','Oops Doughnuts Production').
# studio('You Again','Touchstone Picture').
# studio('You Can Count on Me','Cappa Production').
# studio('You Can Count on Me','Crush Entertainmen').
# studio('You Can Count on Me','Hart-Sharp Entertainmen').
# studio('You Cant Take It With You','Columbia Picture').
# studio('You Dont Mess with the Zohan','Columbia Picture').
# studio('You Dont Mess with the Zohan','Happy Madison Production').
# studio('You Dont Mess with the Zohan','Relativity Medi').
# studio('You Dont Mess with the Zohan','Sony Pictures Releasin').
# studio('You Kill Me','Bi-polar Picture').
# studio('You Kill Me','Carol Baum Production').
# studio('You Kill Me','Code Entertainmen').
# studio('You Kill Me','Dillinger Production').
# studio('You Kill Me','Echo Lake Production').
# studio('You Kill Me','Green Tulip Production').
# studio('You Kill Me','Independent Film Grou').
# studio('You Only Live Twice','Eon Production').
# studio('You Will Meet a Tall Dark Stranger','Antena 3 Film').
# studio('You, Me and Dupree','Kaplan/Perrone Entertainmen').
# studio('You, Me and Dupree','MMCB Film Produktion 200').
# studio('You, Me and Dupree','Universal Picture').
# studio('Young Adult','Denver and Delilah Production').
# studio('Young Adult','Indian Paintbrus').
# studio('Young Adult','Paramount Picture').
# studio('Young Frankenstein','Crossbow Production').
# studio('Young Frankenstein','Gruskoff/Venture Film').
# studio('Young Frankenstein','Jouer Limite').
# studio('Young Frankenstein','Twentieth Century Fox Film Corporatio').
# studio('Young Guns','Morgan Creek Production').
# studio('Young Guns','Twentieth Century Fox Film Corporatio').
# studio('Young Sherlock Holmes','Amblin Entertainmen').
# studio('Young Sherlock Holmes','Paramount Picture').
# studio('Your Highness','Stuber Production').
# studio('Your Highness','Universal Picture').
# studio('Your Sisters Sister','Ada Film').
# studio('Yours, Mine and Ours','Desilu Production').
# studio('Yours, Mine and Ours','Walden Production').
# studio('Youth in Revolt','Dimension Film').
# studio('Youve Got Mail','Warner Bros').
# studio('Z Storm','Pegasus Motion Picture').
# studio('ZMD: Zombies of Mass Destruction','Splendid Fil').
# studio('Zack and Miri Make a Porno','Blue Aske').
# studio('Zack and Miri Make a Porno','View Askew Production').
# studio('Zambezia','120dB Film').
# studio('Zambezia','Cinema Management Grou').
# studio('Zambezia','Industrial Development Corporation of South Afric').
# studio('Zambezia','The Department of Trade and Industry of South Afric').
# studio('Zambezia','The National Film and Video Foundation of S').
# studio('Zambezia','Triggerfish Animatio').
# studio('Zambezia','Wonderful Work').
# studio('Zathura: A Space Adventure','Columbia Pictures Corporatio').
# studio('Zathura: A Space Adventure','Michael De Luca Production').
# studio('Zathura: A Space Adventure','Radar Picture').
# studio('Zathura: A Space Adventure','Teitler Fil').
# studio('Zero Dark Thirty','Annapurna Picture').
# studio('Zero Dark Thirty','Columbia Picture').
# studio('Zero Dark Thirty','First Light Productio').
# studio('Zero Effect','Castle Rock Entertainmen').
# studio('Zero Effect','Columbia Pictures Corporatio').
# studio('Zero Effect','Manifest Film Compan').
# studio('Zipper','33 Picture').
# studio('Zipper','Cargo Entertainmen').
# studio('Zipper','Protozoa Picture').
# studio('Zodiac','Paramount Picture').
# studio('Zodiac','Phoenix Picture').
# studio('Zodiac','Warner Bros').
# studio('Zombie Hunter','Arrowstorm Entertainmen').
# studio('Zombie Hunter','The Klima').
# studio('Zombieland','Columbia Picture').
# studio('Zombieland','Paria').
# studio('Zombieland','Relativity Medi').
# studio('Zookeeper','Broken Road Production').
# studio('Zookeeper','Columbia Picture').
# studio('Zookeeper','Happy Madison Production').
# studio('Zookeeper','Hey Eddi').
# studio('Zookeeper','Metro-Goldwyn-Mayer (MGM').
# studio('Zookeeper','Sony Pictures Releasin').
# studio('Zookeeper','Zookeeper Production').
# studio('Zoolander 2','Red Hour Film').
# studio('Zoolander 2','Scott Rudin Production').
# studio('Zoolander','MFP Munich Film Partners GmbH & Company I. Produktions K').
# studio('Zoolander','NPV Entertainmen').
# studio('Zoolander','Paramount Picture').
# studio('Zoolander','Red Hour Film').
# studio('Zoolander','Red Hour Production').
# studio('Zoolander','Scott Rudin Production').
# studio('Zoolander','Tenth Planet Production').
# studio('Zoolander','VH1 Televisio').
# studio('Zoolander','Village Roadshow Picture').
# studio('Zoom','Columbia Picture').
# studio('Zoom','Revolution Studio').
# studio('Zulu','Canal').
# studio('Zulu','Ciné').
# studio('Zulu','Eskwa').
# studio('Zulu','Lobster Tre').
# studio('Zulu','M6 Film').
# studio('Zulu','Path').
# studio('Zulu','W').
# studio('[REC]','Filma').
# studio('[REC]²','Filma').
# studio('eXistenZ','Alliance Atlantis Communication').
# studio('eXistenZ','Canadian Television Fun').
# studio('eXistenZ','Natural Nylon Entertainmen').
# studio('eXistenZ','Serendipity Point Film').
# studio('eXistenZ','The Harold Greenberg Fun').
# studio('eXistenZ','The Movie Networ').
# studio('eXistenZ','Téléfilm Canad').
# studio('eXistenZ','Union Générale Cinématographiqu').
# studio('xXx','Columbia Picture').
# studio('xXx','Original Fil').
# studio('xXx','Revolution Studio').
# studio('xXx: State of the Union','Columbia Pictures Corporatio').
# studio('xXx: State of the Union','Original Fil').
# studio('xXx: State of the Union','Revolution Studio').
# studio('Æon Flux','Colossal Picture').
# studio('Æon Flux','Lakeshore Entertainmen').
# studio('Æon Flux','MTV Film').
# studio('Æon Flux','MTV Production').
# studio('Æon Flux','Paramount Picture').
# studio('Æon Flux','Valhalla Motion Picture').
# vote_average('#Horror','under_5').
# vote_average('(500) Days of Summer','5-7.5').
# vote_average('10 Cloverfield Lane','5-7.5').
# vote_average('10 Days in a Madhouse','under_5').
# vote_average('10 Things I Hate About You','5-7.5').
# vote_average('102 Dalmatians','5-7.5').
# vote_average('10th & Wolf','5-7.5').
# vote_average('11:14','5-7.5').
# vote_average('12 Angry Men','over7.5').
# vote_average('12 Rounds','5-7.5').
# vote_average('12 Years a Slave','over7.5').
# vote_average('127 Hours','5-7.5').
# vote_average('13 Going on 30','5-7.5').
# vote_average('13 Hours: The Secret Soldiers of Benghazi','5-7.5').
# vote_average('1408','5-7.5').
# vote_average('15 Minutes','5-7.5').
# vote_average('16 Blocks','5-7.5').
# vote_average('16 to Life','under_5').
# vote_average('17 Again','5-7.5').
# vote_average('1776','5-7.5').
# vote_average('1911','5-7.5').
# vote_average('1941','5-7.5').
# vote_average('1982','5-7.5').
# vote_average('2 Fast 2 Furious','5-7.5').
# vote_average('2 Guns','5-7.5').
# vote_average('20 Dates','under_5').
# vote_average('20 Feet from Stardom','5-7.5').
# vote_average('20,000 Leagues Under the Sea','5-7.5').
# vote_average('200 Cigarettes','5-7.5').
# vote_average('2001: A Space Odyssey','over7.5').
# vote_average('2012','5-7.5').
# vote_average('2016: Obamas America','under_5').
# vote_average('2046','5-7.5').
# vote_average('21 & Over','5-7.5').
# vote_average('21 Grams','5-7.5').
# vote_average('21 Jump Street','5-7.5').
# vote_average('21','5-7.5').
# vote_average('22 Jump Street','5-7.5').
# vote_average('24 7: Twenty Four Seven','5-7.5').
# vote_average('25th Hour','5-7.5').
# vote_average('27 Dresses','5-7.5').
# vote_average('28 Days Later','5-7.5').
# vote_average('28 Days','5-7.5').
# vote_average('28 Weeks Later','5-7.5').
# vote_average('2:13','under_5').
# vote_average('3 Backyards','under_5').
# vote_average('3 Days to Kill','5-7.5').
# vote_average('3 Ninjas Kick Back','under_5').
# vote_average('3 Strikes','5-7.5').
# vote_average('30 Days of Night','5-7.5').
# vote_average('30 Minutes or Less','5-7.5').
# vote_average('30 Nights of Paranormal Activity With the Devil Inside the Girl With the Dragon Tattoo','under_5').
# vote_average('300','5-7.5').
# vote_average('3000 Miles to Graceland','5-7.5').
# vote_average('300: Rise of an Empire','5-7.5').
# vote_average('3:10 to Yuma','5-7.5').
# vote_average('4 Months, 3 Weeks and 2 Days','5-7.5').
# vote_average('40 Days and 40 Nights','5-7.5').
# vote_average('42','5-7.5').
# vote_average('42nd Street','5-7.5').
# vote_average('47 Ronin','5-7.5').
# vote_average('5 Days of War','5-7.5').
# vote_average('50 First Dates','5-7.5').
# vote_average('50/50','5-7.5').
# vote_average('51 Birch Street','5-7.5').
# vote_average('54','5-7.5').
# vote_average('55 Days at Peking','5-7.5').
# vote_average('8 Days','under_5').
# vote_average('8 Heads in a Duffel Bag','5-7.5').
# vote_average('8 Mile','5-7.5').
# vote_average('8 Women','5-7.5').
# vote_average('88 Minutes','5-7.5').
# vote_average('8: The Mormon Proposition','5-7.5').
# vote_average('8MM','5-7.5').
# vote_average('9','5-7.5').
# vote_average('90 Minutes in Heaven','5-7.5').
# vote_average('A Beautiful Mind','over7.5').
# vote_average('A Beginners Guide to Snuff','under_5').
# vote_average('A Better Life','5-7.5').
# vote_average('A Bridge Too Far','5-7.5').
# vote_average('A Bugs Life','5-7.5').
# vote_average('A Charlie Brown Christmas','over7.5').
# vote_average('A Christmas Carol','5-7.5').
# vote_average('A Christmas Story','5-7.5').
# vote_average('A Cinderella Story','5-7.5').
# vote_average('A Civil Action','5-7.5').
# vote_average('A Cock and Bull Story','5-7.5').
# vote_average('A Dangerous Method','5-7.5').
# vote_average('A Dog Of Flanders','5-7.5').
# vote_average('A Dogs Breakfast','5-7.5').
# vote_average('A Farewell to Arms','5-7.5').
# vote_average('A Few Good Men','5-7.5').
# vote_average('A Fine Step','under_5').
# vote_average('A Fistful of Dollars','over7.5').
# vote_average('A Funny Thing Happened on the Way to the Forum','5-7.5').
# vote_average('A Good Day to Die Hard','5-7.5').
# vote_average('A Good Year','5-7.5').
# vote_average('A Guy Named Joe','5-7.5').
# vote_average('A Guy Thing','5-7.5').
# vote_average('A Hard Days Night','5-7.5').
# vote_average('A Haunted House 2','5-7.5').
# vote_average('A Haunted House','5-7.5').
# vote_average('A History of Violence','5-7.5').
# vote_average('A Home at the End of the World','5-7.5').
# vote_average('A Knights Tale','5-7.5').
# vote_average('A LEGO Brickumentary','5-7.5').
# vote_average('A League of Their Own','5-7.5').
# vote_average('A Lonely Place to Die','5-7.5').
# vote_average('A Lot Like Love','5-7.5').
# vote_average('A Low Down Dirty Shame','5-7.5').
# vote_average('A Madea Christmas','5-7.5').
# vote_average('A Man Apart','5-7.5').
# vote_average('A Man for All Seasons','over7.5').
# vote_average('A Mighty Heart','5-7.5').
# vote_average('A Mighty Wind','5-7.5').
# vote_average('A Million Ways to Die in the West','5-7.5').
# vote_average('A Monster in Paris','5-7.5').
# vote_average('A Most Violent Year','5-7.5').
# vote_average('A Most Wanted Man','5-7.5').
# vote_average('A Night at the Roxbury','5-7.5').
# vote_average('A Nightmare on Elm Street 3: Dream Warriors','5-7.5').
# vote_average('A Nightmare on Elm Street 4: The Dream Master','5-7.5').
# vote_average('A Nightmare on Elm Street 5: The Dream Child','5-7.5').
# vote_average('A Nightmare on Elm Street Part 2: Freddys Revenge','5-7.5').
# vote_average('A Nightmare on Elm Street','5-7.5').
# vote_average('A Passage to India','5-7.5').
# vote_average('A Perfect Getaway','5-7.5').
# vote_average('A Prairie Home Companion','5-7.5').
# vote_average('A Room for Romeo Brass','5-7.5').
# vote_average('A Room with a View','5-7.5').
# vote_average('A Scanner Darkly','5-7.5').
# vote_average('A Separation','over7.5').
# vote_average('A Serious Man','5-7.5').
# vote_average('A Shine of Rainbows','5-7.5').
# vote_average('A Simple Plan','5-7.5').
# vote_average('A Simple Wish','5-7.5').
# vote_average('A Single Man','5-7.5').
# vote_average('A Sound of Thunder','under_5').
# vote_average('A Streetcar Named Desire','over7.5').
# vote_average('A Tale of Three Cities','5-7.5').
# vote_average('A Thin Line Between Love and Hate','5-7.5').
# vote_average('A Thousand Words','5-7.5').
# vote_average('A Time to Kill','5-7.5').
# vote_average('A True Story','5-7.5').
# vote_average('A Turtles Tale: Sammys Adventures','5-7.5').
# vote_average('A Very Harold & Kumar Christmas','5-7.5').
# vote_average('A Very Long Engagement','5-7.5').
# vote_average('A View to a Kill','5-7.5').
# vote_average('A Walk Among the Tombstones','5-7.5').
# vote_average('A Walk on the Moon','5-7.5').
# vote_average('A Walk to Remember','over7.5').
# vote_average('A Woman, a Gun and a Noodle Shop','under_5').
# vote_average('A.I. Artificial Intelligence','5-7.5').
# vote_average('ABCD (Any Body Can Dance)','5-7.5').
# vote_average('ATL','5-7.5').
# vote_average('AVP: Alien vs. Predator','5-7.5').
# vote_average('AWOL-72','under_5').
# vote_average('Abandon','under_5').
# vote_average('Abandoned','5-7.5').
# vote_average('Abduction','5-7.5').
# vote_average('Aberdeen','5-7.5').
# vote_average('About Last Night','5-7.5').
# vote_average('About Schmidt','5-7.5').
# vote_average('About Time','over7.5').
# vote_average('About a Boy','5-7.5').
# vote_average('Abraham Lincoln: Vampire Hunter','5-7.5').
# vote_average('Absentia','5-7.5').
# vote_average('Absolute Power','5-7.5').
# vote_average('Accidental Love','under_5').
# vote_average('Ace Ventura: Pet Detective','5-7.5').
# vote_average('Ace Ventura: When Nature Calls','5-7.5').
# vote_average('Across the Universe','5-7.5').
# vote_average('Act of Valor','5-7.5').
# vote_average('Action Jackson','under_5').
# vote_average('Adam Resurrected','5-7.5').
# vote_average('Adam','5-7.5').
# vote_average('Adaptation.','5-7.5').
# vote_average('Addicted','5-7.5').
# vote_average('Admission','5-7.5').
# vote_average('Adore','5-7.5').
# vote_average('Adulterers','5-7.5').
# vote_average('Adventureland','5-7.5').
# vote_average('After Earth','5-7.5').
# vote_average('After the Sunset','5-7.5').
# vote_average('After','5-7.5').
# vote_average('After.Life','5-7.5').
# vote_average('Against the Ropes','under_5').
# vote_average('Against the Wild','under_5').
# vote_average('Agent Cody Banks 2: Destination London','5-7.5').
# vote_average('Agent Cody Banks','5-7.5').
# vote_average('Agora','5-7.5').
# vote_average('Aimee & Jaguar','5-7.5').
# vote_average('Air Bud','5-7.5').
# vote_average('Air Force One','5-7.5').
# vote_average('Airborne','5-7.5').
# vote_average('Airlift','5-7.5').
# vote_average('Airplane!','5-7.5').
# vote_average('Ajami','5-7.5').
# vote_average('Akeelah and the Bee','5-7.5').
# vote_average('Akira','over7.5').
# vote_average('Aladdin','5-7.5').
# vote_average('Alatriste','5-7.5').
# vote_average('Albert Nobbs','5-7.5').
# vote_average('Albino Alligator','5-7.5').
# vote_average('Alex & Emma','5-7.5').
# vote_average('Alex Cross','5-7.5').
# vote_average('Alexander and the Terrible, Horrible, No Good, Very Bad Day','5-7.5').
# vote_average('Alexander','5-7.5').
# vote_average('Alexanders Ragtime Band','under_5').
# vote_average('Alfie','5-7.5').
# vote_average('Ali','5-7.5').
# vote_average('Alice Through the Looking Glass','5-7.5').
# vote_average('Alice in Wonderland','5-7.5').
# vote_average('Alien Zone','under_5').
# vote_average('Alien','over7.5').
# vote_average('Alien: Resurrection','5-7.5').
# vote_average('Aliens in the Attic','5-7.5').
# vote_average('Aliens vs Predator: Requiem','under_5').
# vote_average('Aliens','over7.5').
# vote_average('Alien³','5-7.5').
# vote_average('Alive','5-7.5').
# vote_average('All About Steve','under_5').
# vote_average('All About the Benjamins','5-7.5').
# vote_average('All Good Things','5-7.5').
# vote_average('All Hat','under_5').
# vote_average('All Is Bright','5-7.5').
# vote_average('All Is Lost','5-7.5').
# vote_average('All Superheroes Must Die','under_5').
# vote_average('All That Jazz','5-7.5').
# vote_average('All The Queens Men','5-7.5').
# vote_average('All or Nothing','5-7.5').
# vote_average('All the Boys Love Mandy Lane','5-7.5').
# vote_average('All the Kings Men','5-7.5').
# vote_average('All the Pretty Horses','5-7.5').
# vote_average('All the Real Girls','5-7.5').
# vote_average('Allegiant','5-7.5').
# vote_average('Alleluia! The Devils Carnival','5-7.5').
# vote_average('Almost Famous','5-7.5').
# vote_average('Aloft','5-7.5').
# vote_average('Aloha','5-7.5').
# vote_average('Alone With Her','5-7.5').
# vote_average('Alone in the Dark','under_5').
# vote_average('Along Came Polly','5-7.5').
# vote_average('Along Came a Spider','5-7.5').
# vote_average('Along the Roadside','over7.5').
# vote_average('Alpha and Omega','5-7.5').
# vote_average('Alpha and Omega: The Legend of the Saw Tooth Cave','5-7.5').
# vote_average('Alvin and the Chipmunks','5-7.5').
# vote_average('Alvin and the Chipmunks: Chipwrecked','5-7.5').
# vote_average('Alvin and the Chipmunks: The Road Chip','5-7.5').
# vote_average('Alvin and the Chipmunks: The Squeakquel','5-7.5').
# vote_average('Amadeus','over7.5').
# vote_average('Amen.','5-7.5').
# vote_average('America Is Still the Place','under_5').
# vote_average('American Beast','under_5').
# vote_average('American Beauty','over7.5').
# vote_average('American Desi','5-7.5').
# vote_average('American Dreamz','under_5').
# vote_average('American Gangster','5-7.5').
# vote_average('American Graffiti','5-7.5').
# vote_average('American Heist','under_5').
# vote_average('American Hero','5-7.5').
# vote_average('American History X','over7.5').
# vote_average('American Hustle','5-7.5').
# vote_average('American Ninja 2: The Confrontation','under_5').
# vote_average('American Outlaws','5-7.5').
# vote_average('American Pie 2','5-7.5').
# vote_average('American Pie','5-7.5').
# vote_average('American Psycho','5-7.5').
# vote_average('American Reunion','5-7.5').
# vote_average('American Sniper','5-7.5').
# vote_average('American Splendor','5-7.5').
# vote_average('American Wedding','5-7.5').
# vote_average('Americas Sweethearts','5-7.5').
# vote_average('Amidst the Devils Wings','under_5').
# vote_average('Amigo','5-7.5').
# vote_average('Amistad','5-7.5').
# vote_average('Amnesiac','under_5').
# vote_average('Among Giants','under_5').
# vote_average('Amores perros','over7.5').
# vote_average('Amour','over7.5').
# vote_average('Amélie','over7.5').
# vote_average('An Alan Smithee Film: Burn, Hollywood, Burn','under_5').
# vote_average('An American Carol','under_5').
# vote_average('An American Haunting','5-7.5').
# vote_average('An American in Hollywood','under_5').
# vote_average('An Education','5-7.5').
# vote_average('An Everlasting Piece','5-7.5').
# vote_average('An Ideal Husband','5-7.5').
# vote_average('An Inconvenient Truth','5-7.5').
# vote_average('An Unfinished Life','5-7.5').
# vote_average('Anaconda','under_5').
# vote_average('Anacondas: The Hunt for the Blood Orchid','under_5').
# vote_average('Analyze That','5-7.5').
# vote_average('Analyze This','5-7.5').
# vote_average('Anastasia','5-7.5').
# vote_average('Anatomy','5-7.5').
# vote_average('Anchorman 2: The Legend Continues','5-7.5').
# vote_average('Anchorman: The Legend of Ron Burgundy','5-7.5').
# vote_average('And So It Goes','5-7.5').
# vote_average('And Then Came Love','5-7.5').
# vote_average('Andersons Cross','under_5').
# vote_average('Angel Eyes','5-7.5').
# vote_average('Angelas Ashes','5-7.5').
# vote_average('Angels & Demons','5-7.5').
# vote_average('Animal House','5-7.5').
# vote_average('Animals United','5-7.5').
# vote_average('Animals','5-7.5').
# vote_average('Anna Karenina','5-7.5').
# vote_average('Anna and the King','5-7.5').
# vote_average('Annabelle','5-7.5').
# vote_average('Anne of Green Gables','over7.5').
# vote_average('Annie Get Your Gun','5-7.5').
# vote_average('Annie Hall','over7.5').
# vote_average('Annie','5-7.5').
# vote_average('Anomalisa','5-7.5').
# vote_average('Anonymous','5-7.5').
# vote_average('Another Earth','5-7.5').
# vote_average('Another Happy Day','5-7.5').
# vote_average('Another Year','5-7.5').
# vote_average('Ant-Man','5-7.5').
# vote_average('Antarctic Edge: 70° South','under_5').
# vote_average('Antarctica: A Year on Ice','5-7.5').
# vote_average('Antibirth','under_5').
# vote_average('Antitrust','5-7.5').
# vote_average('Antiviral','5-7.5').
# vote_average('Antwone Fisher','5-7.5').
# vote_average('Antz','5-7.5').
# vote_average('Any Given Sunday','5-7.5').
# vote_average('Anything Else','5-7.5').
# vote_average('Anywhere But Here','5-7.5').
# vote_average('Apocalypse Now','over7.5').
# vote_average('Apocalypto','5-7.5').
# vote_average('Apollo 13','5-7.5').
# vote_average('Apollo 18','5-7.5').
# vote_average('Appaloosa','5-7.5').
# vote_average('April Fools Day','5-7.5').
# vote_average('Aqua Teen Hunger Force Colon Movie Film for Theaters','5-7.5').
# vote_average('Aquamarine','5-7.5').
# vote_average('Arachnophobia','5-7.5').
# vote_average('Ararat','5-7.5').
# vote_average('Arbitrage','5-7.5').
# vote_average('Archaeology of a Woman','under_5').
# vote_average('Are We There Yet?','5-7.5').
# vote_average('Area 51','under_5').
# vote_average('Argo','5-7.5').
# vote_average('Arlington Road','5-7.5').
# vote_average('Armageddon','5-7.5').
# vote_average('Armored','5-7.5').
# vote_average('Army of Darkness','5-7.5').
# vote_average('Arn: The Knight Templar','5-7.5').
# vote_average('Around the World in 80 Days','5-7.5').
# vote_average('Aroused','5-7.5').
# vote_average('Arthur Christmas','5-7.5').
# vote_average('Arthur and the Invisibles','5-7.5').
# vote_average('As Above, So Below','5-7.5').
# vote_average('As Good as It Gets','5-7.5').
# vote_average('As It Is in Heaven','5-7.5').
# vote_average('Ask Me Anything','5-7.5').
# vote_average('Assassins','5-7.5').
# vote_average('Assault on Precinct 13','5-7.5').
# vote_average('Asterix at the Olympic Games','5-7.5').
# vote_average('Astro Boy','5-7.5').
# vote_average('At First Sight','5-7.5').
# vote_average('Atlantis: The Lost Empire','5-7.5').
# vote_average('Atlas Shrugged Part II','5-7.5').
# vote_average('Atlas Shrugged Part III: Who is John Galt?','under_5').
# vote_average('Atonement','5-7.5').
# vote_average('Attack the Block','5-7.5').
# vote_average('August Rush','5-7.5').
# vote_average('August','5-7.5').
# vote_average('August: Osage County','5-7.5').
# vote_average('Austin Powers in Goldmember','5-7.5').
# vote_average('Austin Powers: International Man of Mystery','5-7.5').
# vote_average('Austin Powers: The Spy Who Shagged Me','5-7.5').
# vote_average('Australia','5-7.5').
# vote_average('Auto Focus','5-7.5').
# vote_average('Automata','5-7.5').
# vote_average('Autumn in New York','5-7.5').
# vote_average('Avatar','5-7.5').
# vote_average('Avengers: Age of Ultron','5-7.5').
# vote_average('Awake','5-7.5').
# vote_average('Away We Go','5-7.5').
# vote_average('Ayurveda: Art of Being','5-7.5').
# vote_average('B-Girl','5-7.5').
# vote_average('Baahubali: The Beginning','over7.5').
# vote_average('Babe','5-7.5').
# vote_average('Babe: Pig in the City','5-7.5').
# vote_average('Babel','5-7.5').
# vote_average('Baby Boy','5-7.5').
# vote_average('Baby Geniuses','under_5').
# vote_average('Baby Mama','5-7.5').
# vote_average('Babylon A.D.','5-7.5').
# vote_average('Babys Day Out','5-7.5').
# vote_average('Bachelorette','5-7.5').
# vote_average('Back to the Future Part II','5-7.5').
# vote_average('Back to the Future Part III','5-7.5').
# vote_average('Back to the Future','over7.5').
# vote_average('Backmask','under_5').
# vote_average('Bad Boys II','5-7.5').
# vote_average('Bad Boys','5-7.5').
# vote_average('Bad Company','5-7.5').
# vote_average('Bad Grandpa','5-7.5').
# vote_average('Bad Moms','5-7.5').
# vote_average('Bad Santa','5-7.5').
# vote_average('Bad Teacher','5-7.5').
# vote_average('Bad Words','5-7.5').
# vote_average('Baggage Claim','5-7.5').
# vote_average('Baghead','5-7.5').
# vote_average('Bait','5-7.5').
# vote_average('Ballistic: Ecks vs. Sever','under_5').
# vote_average('Bambi','5-7.5').
# vote_average('Bamboozled','5-7.5').
# vote_average('Bananas','5-7.5').
# vote_average('Bandidas','5-7.5').
# vote_average('Bandits','5-7.5').
# vote_average('Bandslam','5-7.5').
# vote_average('Bang Bang Baby','5-7.5').
# vote_average('Bang','5-7.5').
# vote_average('Bangkok Dangerous','5-7.5').
# vote_average('Banshee Chapter','5-7.5').
# vote_average('Barbarella','5-7.5').
# vote_average('Barbecue','5-7.5').
# vote_average('Barbershop 2:  Back in Business','5-7.5').
# vote_average('Barbershop','5-7.5').
# vote_average('Barneys Great Adventure','under_5').
# vote_average('Barneys Version','5-7.5').
# vote_average('Barnyard','5-7.5').
# vote_average('Barry Lyndon','over7.5').
# vote_average('Barry Munday','5-7.5').
# vote_average('Basic Instinct 2','under_5').
# vote_average('Basic','5-7.5').
# vote_average('Basquiat','5-7.5').
# vote_average('Bathing Beauty','5-7.5').
# vote_average('Bathory: Countess of Blood','5-7.5').
# vote_average('Batman & Robin','under_5').
# vote_average('Batman Begins','over7.5').
# vote_average('Batman Forever','5-7.5').
# vote_average('Batman Returns','5-7.5').
# vote_average('Batman v Superman: Dawn of Justice','5-7.5').
# vote_average('Batman','5-7.5').
# vote_average('Batman','5-7.5').
# vote_average('Batman: The Dark Knight Returns, Part 2','over7.5').
# vote_average('Bats','under_5').
# vote_average('Battle for the Planet of the Apes','5-7.5').
# vote_average('Battle of the Year','5-7.5').
# vote_average('Battle: Los Angeles','5-7.5').
# vote_average('Battlefield Earth','under_5').
# vote_average('Battleship','5-7.5').
# vote_average('Be Cool','5-7.5').
# vote_average('Be Kind Rewind','5-7.5').
# vote_average('Beastly','5-7.5').
# vote_average('Beastmaster 2: Through the Portal of Time','under_5').
# vote_average('Beasts of the Southern Wild','5-7.5').
# vote_average('Beat the World','under_5').
# vote_average('Beautiful Creatures','5-7.5').
# vote_average('Beauty Shop','5-7.5').
# vote_average('Beavis and Butt-Head Do America','5-7.5').
# vote_average('Because I Said So','5-7.5').
# vote_average('Because of Winn-Dixie','5-7.5').
# vote_average('Becoming Jane','5-7.5').
# vote_average('Bedazzled','5-7.5').
# vote_average('Bedtime Stories','5-7.5').
# vote_average('Bee Movie','5-7.5').
# vote_average('Beer League','5-7.5').
# vote_average('Beerfest','5-7.5').
# vote_average('Beetlejuice','5-7.5').
# vote_average('Before I Go to Sleep','5-7.5').
# vote_average('Before Midnight','5-7.5').
# vote_average('Before Sunrise','over7.5').
# vote_average('Before Sunset','over7.5').
# vote_average('Begin Again','5-7.5').
# vote_average('Beginners','5-7.5').
# vote_average('Behind Enemy Lines','5-7.5').
# vote_average('Being John Malkovich','5-7.5').
# vote_average('Being Julia','5-7.5').
# vote_average('Bella','5-7.5').
# vote_average('Beloved','5-7.5').
# vote_average('Below Zero','under_5').
# vote_average('Ben-Hur','5-7.5').
# vote_average('Bend It Like Beckham','5-7.5').
# vote_average('Bending Steel','5-7.5').
# vote_average('Beneath Hill 60','5-7.5').
# vote_average('Beneath the Planet of the Apes','5-7.5').
# vote_average('Benji','5-7.5').
# vote_average('Beowulf','5-7.5').
# vote_average('Bernie','5-7.5').
# vote_average('Best in Show','5-7.5').
# vote_average('Better Luck Tomorrow','5-7.5').
# vote_average('Betty Fisher and Other Stories','5-7.5').
# vote_average('Beverly Hills Chihuahua','under_5').
# vote_average('Beverly Hills Cop II','5-7.5').
# vote_average('Beverly Hills Cop III','5-7.5').
# vote_average('Beverly Hills Cop','5-7.5').
# vote_average('Beyond Borders','5-7.5').
# vote_average('Beyond the Black Rainbow','5-7.5').
# vote_average('Beyond the Lights','5-7.5').
# vote_average('Beyond the Mat','over7.5').
# vote_average('Beyond the Sea','5-7.5').
# vote_average('Beyond the Valley of the Dolls','5-7.5').
# vote_average('Bicentennial Man','5-7.5').
# vote_average('Big Daddy','5-7.5').
# vote_average('Big Eyes','5-7.5').
# vote_average('Big Fat Liar','5-7.5').
# vote_average('Big Fish','over7.5').
# vote_average('Big Hero 6','over7.5').
# vote_average('Big Miracle','5-7.5').
# vote_average('Big Mommas House 2','5-7.5').
# vote_average('Big Mommas House','5-7.5').
# vote_average('Big Mommas: Like Father, Like Son','5-7.5').
# vote_average('Big Trouble in Little China','5-7.5').
# vote_average('Big Trouble','5-7.5').
# vote_average('Big','5-7.5').
# vote_average('Bill & Teds Bogus Journey','5-7.5').
# vote_average('Bill & Teds Excellent Adventure','5-7.5').
# vote_average('Billy Elliot','5-7.5').
# vote_average('Birdman','5-7.5').
# vote_average('Birth','5-7.5').
# vote_average('Birthday Girl','5-7.5').
# vote_average('Biutiful','5-7.5').
# vote_average('Bizarre','5-7.5').
# vote_average('Black Book','5-7.5').
# vote_average('Black Christmas','under_5').
# vote_average('Black Hawk Down','5-7.5').
# vote_average('Black Knight','5-7.5').
# vote_average('Black Mass','5-7.5').
# vote_average('Black Nativity','5-7.5').
# vote_average('Black November','5-7.5').
# vote_average('Black Rain','5-7.5').
# vote_average('Black Rock','under_5').
# vote_average('Black Snake Moan','5-7.5').
# vote_average('Black Swan','5-7.5').
# vote_average('Black Water Transit','under_5').
# vote_average('Black or White','5-7.5').
# vote_average('Blackhat','5-7.5').
# vote_average('Blackthorn','5-7.5').
# vote_average('Blade II','5-7.5').
# vote_average('Blade Runner','over7.5').
# vote_average('Blade','5-7.5').
# vote_average('Blade: Trinity','5-7.5').
# vote_average('Blades of Glory','5-7.5').
# vote_average('Blast from the Past','5-7.5').
# vote_average('Blazing Saddles','5-7.5').
# vote_average('Bled','under_5').
# vote_average('Bleeding Hearts','under_5').
# vote_average('Blended','5-7.5').
# vote_average('Bless the Child','under_5').
# vote_average('Blindness','5-7.5').
# vote_average('Blonde Ambition','under_5').
# vote_average('Blood Diamond','5-7.5').
# vote_average('Blood Done Sign My Name','5-7.5').
# vote_average('Blood Ties','5-7.5').
# vote_average('Blood Work','5-7.5').
# vote_average('Blood and Chocolate','5-7.5').
# vote_average('Blood and Wine','5-7.5').
# vote_average('BloodRayne','under_5').
# vote_average('Bloodsport','5-7.5').
# vote_average('Bloody Sunday','5-7.5').
# vote_average('Blow Out','5-7.5').
# vote_average('Blow','5-7.5').
# vote_average('Blue Car','5-7.5').
# vote_average('Blue Crush','5-7.5').
# vote_average('Blue Jasmine','5-7.5').
# vote_average('Blue Like Jazz','5-7.5').
# vote_average('Blue Ruin','5-7.5').
# vote_average('Blue Streak','5-7.5').
# vote_average('Blue Valentine','5-7.5').
# vote_average('Boat Trip','under_5').
# vote_average('Bobby Jones: Stroke of Genius','5-7.5').
# vote_average('Bobby','5-7.5').
# vote_average('Body Double','5-7.5').
# vote_average('Body of Lies','5-7.5').
# vote_average('Bodyguards and Assassins','5-7.5').
# vote_average('Bogus','5-7.5').
# vote_average('Boiler Room','5-7.5').
# vote_average('Bolt','5-7.5').
# vote_average('Bon Cop Bad Cop','5-7.5').
# vote_average('Bon voyage','5-7.5').
# vote_average('Boogeyman','under_5').
# vote_average('Boogie Nights','over7.5').
# vote_average('Book of Shadows: Blair Witch 2','under_5').
# vote_average('Boom Town','5-7.5').
# vote_average('Boomerang','5-7.5').
# vote_average('Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan','5-7.5').
# vote_average('Born Of War','under_5').
# vote_average('Born on the Fourth of July','5-7.5').
# vote_average('Born to Fly: Elizabeth Streb vs. Gravity','5-7.5').
# vote_average('Bottle Rocket','5-7.5').
# vote_average('Bottle Shock','5-7.5').
# vote_average('Bound by Honor','over7.5').
# vote_average('Bound','5-7.5').
# vote_average('Bowfinger','5-7.5').
# vote_average('Bowling for Columbine','5-7.5').
# vote_average('Boyhood','over7.5').
# vote_average('Boynton Beach Club','5-7.5').
# vote_average('Boys Dont Cry','5-7.5').
# vote_average('Boys and Girls','5-7.5').
# vote_average('Boyz n the Hood','5-7.5').
# vote_average('Bran Nue Dae','5-7.5').
# vote_average('Brave New Girl','under_5').
# vote_average('Brave','5-7.5').
# vote_average('Braveheart','over7.5').
# vote_average('Brazil','over7.5').
# vote_average('Breakdown','5-7.5').
# vote_average('Breakfast of Champions','5-7.5').
# vote_average('Breakin All the Rules','5-7.5').
# vote_average('Breaking Upwards','5-7.5').
# vote_average('Brick Lane','5-7.5').
# vote_average('Brick Mansions','5-7.5').
# vote_average('Bride & Prejudice','5-7.5').
# vote_average('Bride Wars','5-7.5').
# vote_average('Bride of Chucky','5-7.5').
# vote_average('Bridesmaids','5-7.5').
# vote_average('Bridge of Spies','5-7.5').
# vote_average('Bridge to Terabithia','5-7.5').
# vote_average('Bridget Jones: The Edge of Reason','5-7.5').
# vote_average('Bridget Joness Diary','5-7.5').
# vote_average('Brigham City','5-7.5').
# vote_average('Bright Lights, Big City','under_5').
# vote_average('Bright Star','5-7.5').
# vote_average('Brighton Rock','5-7.5').
# vote_average('Bring It On','5-7.5').
# vote_average('Bringing Down the House','5-7.5').
# vote_average('Bringing Out the Dead','5-7.5').
# vote_average('Brokeback Mountain','over7.5').
# vote_average('Brokedown Palace','5-7.5').
# vote_average('Broken Arrow','5-7.5').
# vote_average('Broken City','5-7.5').
# vote_average('Broken Horses','5-7.5').
# vote_average('Broken Vessels','5-7.5').
# vote_average('Bronson','5-7.5').
# vote_average('Brooklyn Rules','5-7.5').
# vote_average('Brooklyn','5-7.5').
# vote_average('Brooklyns Finest','5-7.5').
# vote_average('Brother','5-7.5').
# vote_average('Brotherly Love','5-7.5').
# vote_average('Brothers','5-7.5').
# vote_average('Brown Sugar','5-7.5').
# vote_average('Bruce Almighty','5-7.5').
# vote_average('Brüno','5-7.5').
# vote_average('Bubba Ho-tep','5-7.5').
# vote_average('Bubble Boy','5-7.5').
# vote_average('Bucky Larson: Born to Be a Star','under_5').
# vote_average('Buffalo 66','5-7.5').
# vote_average('Buffalo Soldiers','5-7.5').
# vote_average('Bullet to the Head','5-7.5').
# vote_average('Bulletproof Monk','5-7.5').
# vote_average('Bullets Over Broadway','5-7.5').
# vote_average('Bully','5-7.5').
# vote_average('Bulworth','5-7.5').
# vote_average('Buried','5-7.5').
# vote_average('Burlesque','5-7.5').
# vote_average('Burn After Reading','5-7.5').
# vote_average('Burn','5-7.5').
# vote_average('Burnt','5-7.5').
# vote_average('But Im a Cheerleader','5-7.5').
# vote_average('Butch Cassidy and the Sundance Kid','5-7.5').
# vote_average('Butterfly Girl','under_5').
# vote_average('Butterfly on a Wheel','5-7.5').
# vote_average('Butterfly','5-7.5').
# vote_average('By the Sea','5-7.5').
# vote_average('C.H.U.D.','5-7.5').
# vote_average('CJ7','5-7.5').
# vote_average('Ca$h','5-7.5').
# vote_average('Cabin Fever','under_5').
# vote_average('Caddyshack','5-7.5').
# vote_average('Cadillac Records','5-7.5').
# vote_average('Call + Response','over7.5').
# vote_average('Camping Sauvage','under_5').
# vote_average('Cant Hardly Wait','5-7.5').
# vote_average('Cant Stop the Music','under_5').
# vote_average('Cape Fear','5-7.5').
# vote_average('Capitalism: A Love Story','5-7.5').
# vote_average('Capote','5-7.5').
# vote_average('Capricorn One','5-7.5').
# vote_average('Captain America: Civil War','5-7.5').
# vote_average('Captain America: The First Avenger','5-7.5').
# vote_average('Captain America: The Winter Soldier','over7.5').
# vote_average('Captain Corellis Mandolin','5-7.5').
# vote_average('Captain Phillips','over7.5').
# vote_average('Captive','5-7.5').
# vote_average('Caramel','5-7.5').
# vote_average('Caravans','5-7.5').
# vote_average('Cargo','5-7.5').
# vote_average('Carlos','5-7.5').
# vote_average('Carnage','5-7.5').
# vote_average('Carousel of Revenge','under_5').
# vote_average('Carrie','5-7.5').
# vote_average('Carriers','5-7.5').
# vote_average('Cars 2','5-7.5').
# vote_average('Cars','5-7.5').
# vote_average('Casa De Mi Padre','5-7.5').
# vote_average('Casablanca','over7.5').
# vote_average('Case 39','5-7.5').
# vote_average('Casino Jack','5-7.5').
# vote_average('Casino Royale','5-7.5').
# vote_average('Casino','over7.5').
# vote_average('Casper','5-7.5').
# vote_average('Cast Away','over7.5').
# vote_average('Cat People','5-7.5').
# vote_average('Cat on a Hot Tin Roof','over7.5').
# vote_average('Catch Me If You Can','over7.5').
# vote_average('Catch That Kid','under_5').
# vote_average('Catch a Fire','5-7.5').
# vote_average('Catch-22','5-7.5').
# vote_average('Cats & Dogs 2 : The Revenge of Kitty Galore','under_5').
# vote_average('Cats & Dogs','5-7.5').
# vote_average('Cats Dont Dance','5-7.5').
# vote_average('Catwoman','under_5').
# vote_average('Cavite','over7.5').
# vote_average('Cecil B. Demented','5-7.5').
# vote_average('Cedar Rapids','5-7.5').
# vote_average('Celebrity','5-7.5').
# vote_average('Celeste & Jesse Forever','5-7.5').
# vote_average('Cellular','5-7.5').
# vote_average('Censored Voices','5-7.5').
# vote_average('Center Stage','5-7.5').
# vote_average('Central Intelligence','5-7.5').
# vote_average('Central Station','over7.5').
# vote_average('Centurion','5-7.5').
# vote_average('Certifiably Jonathan','under_5').
# vote_average('Chain Letter','under_5').
# vote_average('Chain Reaction','5-7.5').
# vote_average('Chain of Command','5-7.5').
# vote_average('Chairman of the Board','under_5').
# vote_average('Changeling','5-7.5').
# vote_average('Changing Lanes','5-7.5').
# vote_average('Chappie','5-7.5').
# vote_average('Character','over7.5').
# vote_average('Chariots of Fire','5-7.5').
# vote_average('Charlie Bartlett','5-7.5').
# vote_average('Charlie St. Cloud','5-7.5').
# vote_average('Charlie Wilsons War','5-7.5').
# vote_average('Charlie and the Chocolate Factory','5-7.5').
# vote_average('Charlies Angels','5-7.5').
# vote_average('Charlies Angels: Full Throttle','5-7.5').
# vote_average('Charlottes Web','5-7.5').
# vote_average('Charly','5-7.5').
# vote_average('Chasing Amy','5-7.5').
# vote_average('Chasing Liberty','5-7.5').
# vote_average('Chasing Mavericks','5-7.5').
# vote_average('Chasing Papi','5-7.5').
# vote_average('Cheap Thrills','5-7.5').
# vote_average('Cheaper by the Dozen 2','5-7.5').
# vote_average('Cheaper by the Dozen','5-7.5').
# vote_average('Checkmate','under_5').
# vote_average('Cheri','5-7.5').
# vote_average('Chernobyl Diaries','under_5').
# vote_average('Chiamatemi Francesco - Il Papa della gente','5-7.5').
# vote_average('Chicago Overcoat','5-7.5').
# vote_average('Chicago','5-7.5').
# vote_average('Chicken Little','5-7.5').
# vote_average('Chicken Run','5-7.5').
# vote_average('Chicken Tikka Masala','under_5').
# vote_average('Child 44','5-7.5').
# vote_average('Childless','under_5').
# vote_average('Children of Heaven','over7.5').
# vote_average('Children of Men','5-7.5').
# vote_average('Childs Play 2','5-7.5').
# vote_average('Childs Play','5-7.5').
# vote_average('Chill Factor','5-7.5').
# vote_average('Chloe','5-7.5').
# vote_average('Chocolat','5-7.5').
# vote_average('Chocolate: Deep Dark Secrets','under_5').
# vote_average('Choke','5-7.5').
# vote_average('Christmas Eve','5-7.5').
# vote_average('Christmas Mail','5-7.5').
# vote_average('Christmas with the Kranks','5-7.5').
# vote_average('Chronicle','5-7.5').
# vote_average('Chuck & Buck','5-7.5').
# vote_average('Cinco de Mayo: La Batalla','5-7.5').
# vote_average('Cinderella Man','5-7.5').
# vote_average('Cinderella','5-7.5').
# vote_average('Circle','5-7.5').
# vote_average('Circumstance','5-7.5').
# vote_average('Cirque du Freak: The Vampires Assistant','5-7.5').
# vote_average('Cirque du Soleil: Worlds Away','5-7.5').
# vote_average('City By The Sea','5-7.5').
# vote_average('City Hall','5-7.5').
# vote_average('City Island','5-7.5').
# vote_average('City of Angels','5-7.5').
# vote_average('City of Ember','5-7.5').
# vote_average('City of Ghosts','5-7.5').
# vote_average('City of God','over7.5').
# vote_average('City of Life and Death','over7.5').
# vote_average('Civil Brand','5-7.5').
# vote_average('Clash of the Titans','5-7.5').
# vote_average('Class of 1984','5-7.5').
# vote_average('Clay Pigeons','5-7.5').
# vote_average('Clean','5-7.5').
# vote_average('Clear and Present Danger','5-7.5').
# vote_average('Cleopatra','5-7.5').
# vote_average('Clerks II','5-7.5').
# vote_average('Clerks','5-7.5').
# vote_average('Click','5-7.5').
# vote_average('Cliffhanger','5-7.5').
# vote_average('Clockstoppers','under_5').
# vote_average('Clockwatchers','5-7.5').
# vote_average('Close Encounters of the Third Kind','5-7.5').
# vote_average('Close Range','under_5').
# vote_average('Closer to the Moon','5-7.5').
# vote_average('Closer','5-7.5').
# vote_average('Cloud Atlas','5-7.5').
# vote_average('Cloudy with a Chance of Meatballs 2','5-7.5').
# vote_average('Cloudy with a Chance of Meatballs','5-7.5').
# vote_average('Cloverfield','5-7.5').
# vote_average('Club Dread','5-7.5').
# vote_average('Clueless','5-7.5').
# vote_average('Coach Carter','5-7.5').
# vote_average('Coal Miners Daughter','5-7.5').
# vote_average('Coco Before Chanel','5-7.5').
# vote_average('Code 46','5-7.5').
# vote_average('Code Name: The Cleaner','under_5').
# vote_average('Code of Honor','under_5').
# vote_average('Coffee Town','5-7.5').
# vote_average('Cold Mountain','5-7.5').
# vote_average('Collateral Damage','5-7.5').
# vote_average('Collateral','5-7.5').
# vote_average('College','under_5').
# vote_average('Colombiana','5-7.5').
# vote_average('Come Early Morning','5-7.5').
# vote_average('Coming Home','5-7.5').
# vote_average('Commando','5-7.5').
# vote_average('Compadres','5-7.5').
# vote_average('Compliance','5-7.5').
# vote_average('Con Air','5-7.5').
# vote_average('Conan the Barbarian','5-7.5').
# vote_average('Conan the Destroyer','5-7.5').
# vote_average('Concussion','5-7.5').
# vote_average('Confessions of a Dangerous Mind','5-7.5').
# vote_average('Confessions of a Teenage Drama Queen','5-7.5').
# vote_average('Confidence','5-7.5').
# vote_average('Congo','5-7.5').
# vote_average('Connie and Carla','5-7.5').
# vote_average('Conquest of the Planet of the Apes','5-7.5').
# vote_average('Conspiracy Theory','5-7.5').
# vote_average('Contact','5-7.5').
# vote_average('Contagion','5-7.5').
# vote_average('Containment','5-7.5').
# vote_average('Contraband','5-7.5').
# vote_average('Control','over7.5').
# vote_average('Conversations with Other Women','5-7.5').
# vote_average('Cool Runnings','5-7.5').
# vote_average('Cop Land','5-7.5').
# vote_average('Cop Out','5-7.5').
# vote_average('Copycat','5-7.5').
# vote_average('Copying Beethoven','5-7.5').
# vote_average('Coraline','5-7.5').
# vote_average('Coriolanus','5-7.5').
# vote_average('Corky Romano','under_5').
# vote_average('Corpse Bride','5-7.5').
# vote_average('Cotton Comes to Harlem','5-7.5').
# vote_average('Counting','over7.5').
# vote_average('Country Strong','5-7.5').
# vote_average('Couples Retreat','5-7.5').
# vote_average('Courage Under Fire','5-7.5').
# vote_average('Courageous','5-7.5').
# vote_average('Coyote Ugly','5-7.5').
# vote_average('Cradle 2 the Grave','5-7.5').
# vote_average('Cradle Will Rock','5-7.5').
# vote_average('Crank','5-7.5').
# vote_average('Crank: High Voltage','5-7.5').
# vote_average('Crash','5-7.5').
# vote_average('Crazy Heart','5-7.5').
# vote_average('Crazy Stone','5-7.5').
# vote_average('Crazy in Alabama','5-7.5').
# vote_average('Crazy, Stupid, Love.','5-7.5').
# vote_average('Crazy/Beautiful','5-7.5').
# vote_average('Creative Control','5-7.5').
# vote_average('Creature','under_5').
# vote_average('Creed','5-7.5').
# vote_average('Creepshow 2','5-7.5').
# vote_average('Creepshow','5-7.5').
# vote_average('Cries and Whispers','over7.5').
# vote_average('Criminal Activities','5-7.5').
# vote_average('Criminal','5-7.5').
# vote_average('Crimson Tide','5-7.5').
# vote_average('Critical Care','5-7.5').
# vote_average('Crocodile Dundee II','5-7.5').
# vote_average('Crocodile Dundee in Los Angeles','under_5').
# vote_average('Crocodile Dundee','5-7.5').
# vote_average('Crooklyn','5-7.5').
# vote_average('Crossover','under_5').
# vote_average('Crossroads','under_5').
# vote_average('Crouching Tiger, Hidden Dragon','5-7.5').
# vote_average('Crowsnest','under_5').
# vote_average('Cruel Intentions','5-7.5').
# vote_average('Cry Freedom','5-7.5').
# vote_average('Cry_Wolf','5-7.5').
# vote_average('Crying with Laughter','5-7.5').
# vote_average('Cube','5-7.5').
# vote_average('Cure','5-7.5').
# vote_average('Curious George','5-7.5').
# vote_average('Curse of the Golden Flower','5-7.5').
# vote_average('Cursed','5-7.5').
# vote_average('Cutthroat Island','5-7.5').
# vote_average('Cypher','5-7.5').
# vote_average('Cyrus','5-7.5').
# vote_average('D-Tox','5-7.5').
# vote_average('D.E.B.S.','5-7.5').
# vote_average('DOA: Dead or Alive','5-7.5').
# vote_average('Da Sweet Blood of Jesus','under_5').
# vote_average('Daddy Day Camp','under_5').
# vote_average('Daddy Day Care','5-7.5').
# vote_average('Daddys Home','5-7.5').
# vote_average('Dallas Buyers Club','over7.5').
# vote_average('Damnation Alley','5-7.5').
# vote_average('Damsels in Distress','5-7.5').
# vote_average('Dance Flick','under_5').
# vote_average('Dancer in the Dark','over7.5').
# vote_average('Dancer, Texas Pop. 81','over7.5').
# vote_average('Dances with Wolves','over7.5').
# vote_average('Dancin Its On','under_5').
# vote_average('Dangerous Liaisons','5-7.5').
# vote_average('Danny Collins','5-7.5').
# vote_average('Dantes Peak','5-7.5').
# vote_average('Dark Blue','5-7.5').
# vote_average('Dark City','5-7.5').
# vote_average('Dark Shadows','5-7.5').
# vote_average('Dark Water','5-7.5').
# vote_average('Darkness Falls','under_5').
# vote_average('Darkness','5-7.5').
# vote_average('Darling Companion','5-7.5').
# vote_average('Darling Lili','under_5').
# vote_average('Das Boot','over7.5').
# vote_average('Date Movie','under_5').
# vote_average('Date Night','5-7.5').
# vote_average('Dave Chappelles Block Party','5-7.5').
# vote_average('Dawn of the Crescent Moon','under_5').
# vote_average('Dawn of the Dead','5-7.5').
# vote_average('Dawn of the Planet of the Apes','5-7.5').
# vote_average('Day of the Dead','5-7.5').
# vote_average('Daybreakers','5-7.5').
# vote_average('Daylight','5-7.5').
# vote_average('Days of Heaven','over7.5').
# vote_average('Days of Thunder','5-7.5').
# vote_average('Dazed and Confused','5-7.5').
# vote_average('De-Lovely','5-7.5').
# ...
# vote_average('Thunderball','5-7.5').
# vote_average('Thunderbirds','under_5').
# vote_average('Tidal Wave','5-7.5').
# vote_average('Tiger Orange','5-7.5').
# vote_average('Tim and Erics Billion Dollar Movie','5-7.5').
# vote_average('Timber Falls','5-7.5').
# vote_average('Time Bandits','5-7.5').
# vote_average('Time Changer','5-7.5').
# vote_average('Time to Choose','under_5').
# vote_average('Timecop','5-7.5').
# vote_average('Timecrimes','5-7.5').
# vote_average('Timeline','5-7.5').
# vote_average('Tin Can Man','under_5').
# vote_average('Tin Cup','5-7.5').
# vote_average('Tinker Tailor Soldier Spy','5-7.5').
# vote_average('Tiny Furniture','5-7.5').
# vote_average('Titan A.E.','5-7.5').
# vote_average('Titanic','over7.5').
# vote_average('To Be Frank, Sinatra at 100','under_5').
# vote_average('To Die For','5-7.5').
# vote_average('To Kill a Mockingbird','over7.5').
# vote_average('To Rome with Love','5-7.5').
# vote_average('To Save A Life','5-7.5').
# vote_average('To Write Love on Her Arms','5-7.5').
# vote_average('Tom Jones','5-7.5').
# vote_average('Tombstone','5-7.5').
# vote_average('Tomcats','under_5').
# vote_average('Tomorrow Never Dies','5-7.5').
# vote_average('Tomorrowland','5-7.5').
# vote_average('Tootsie','5-7.5').
# vote_average('Top Cat Begins','5-7.5').
# vote_average('Top Five','5-7.5').
# vote_average('Top Gun','5-7.5').
# vote_average('Top Hat','5-7.5').
# vote_average('Top Spin','5-7.5').
# vote_average('Topaz','5-7.5').
# vote_average('Topsy-Turvy','5-7.5').
# vote_average('Tora! Tora! Tora!','5-7.5').
# vote_average('Torn Curtain','5-7.5').
# vote_average('Torque','under_5').
# vote_average('Total Recall','5-7.5').
# vote_average('Touching the Void','over7.5').
# vote_average('Tower Heist','5-7.5').
# vote_average('Town & Country','under_5').
# vote_average('Toy Story 2','5-7.5').
# vote_average('Toy Story 3','over7.5').
# vote_average('Toy Story','over7.5').
# vote_average('Tracker','5-7.5').
# vote_average('Trade Of Innocents','5-7.5').
# vote_average('Trade','5-7.5').
# vote_average('Trading Places','5-7.5').
# vote_average('Traffic','5-7.5').
# vote_average('Train','under_5').
# vote_average('Training Day','5-7.5').
# vote_average('Trainspotting','over7.5').
# vote_average('Trainwreck','5-7.5').
# vote_average('Trance','5-7.5').
# vote_average('Transamerica','5-7.5').
# vote_average('Transcendence','5-7.5').
# vote_average('Transformers','5-7.5').
# vote_average('Transformers: Age of Extinction','5-7.5').
# vote_average('Transformers: Dark of the Moon','5-7.5').
# vote_average('Transformers: Revenge of the Fallen','5-7.5').
# vote_average('Transporter 2','5-7.5').
# vote_average('Transsiberian','5-7.5').
# vote_average('Trapeze','5-7.5').
# vote_average('Trash','5-7.5').
# vote_average('Travellers and Magicians','5-7.5').
# vote_average('Treachery','under_5').
# vote_average('Treading Water','5-7.5').
# vote_average('Treasure Planet','5-7.5').
# vote_average('Trees Lounge','5-7.5').
# vote_average('Trekkies','5-7.5').
# vote_average('Tremors','5-7.5').
# vote_average('Triangle','5-7.5').
# vote_average('Triple 9','5-7.5').
# vote_average('Trippin','under_5').
# vote_average('Troll Hunter','5-7.5').
# vote_average('Troop Beverly Hills','5-7.5').
# vote_average('Tropic Thunder','5-7.5').
# vote_average('Trouble with the Curve','5-7.5').
# vote_average('Troy','5-7.5').
# vote_average('Trucker','5-7.5').
# vote_average('True Grit','5-7.5').
# vote_average('True Lies','5-7.5').
# vote_average('True Romance','over7.5').
# vote_average('Trust the Man','5-7.5').
# vote_average('Trust','5-7.5').
# vote_average('Truth or Dare','5-7.5').
# vote_average('Tsotsi','5-7.5').
# vote_average('Tuck Everlasting','5-7.5').
# vote_average('Tucker and Dale vs Evil','5-7.5').
# vote_average('Tumbleweeds','5-7.5').
# vote_average('Tupac: Resurrection','over7.5').
# vote_average('Turbo','5-7.5').
# vote_average('Turbulence','5-7.5').
# vote_average('Tusk','5-7.5').
# vote_average('Twilight Zone: The Movie','5-7.5').
# vote_average('Twilight','5-7.5').
# vote_average('Twin Falls Idaho','5-7.5').
# vote_average('Twins','5-7.5').
# vote_average('Twister','5-7.5').
# vote_average('Twixt','5-7.5').
# vote_average('Two Brothers','5-7.5').
# vote_average('Two Can Play That Game','5-7.5').
# vote_average('Two Evil Eyes','5-7.5').
# vote_average('Two Girls and a Guy','5-7.5').
# vote_average('Two Lovers and a Bear','5-7.5').
# vote_average('Two Lovers','5-7.5').
# vote_average('Two Weeks Notice','5-7.5').
# vote_average('Tycoon','5-7.5').
# vote_average('U-571','5-7.5').
# vote_average('U.F.O.','under_5').
# vote_average('U2 3D','5-7.5').
# vote_average('UHF','5-7.5').
# vote_average('Ulees Gold','5-7.5').
# vote_average('Ultramarines: A Warhammer 40,000 Movie','5-7.5').
# vote_average('Ultraviolet','under_5').
# vote_average('UnDivided','under_5').
# vote_average('Unaccompanied Minors','5-7.5').
# vote_average('Unbreakable','5-7.5').
# vote_average('Unbroken','5-7.5').
# vote_average('Under Siege 2: Dark Territory','5-7.5').
# vote_average('Under the Rainbow','under_5').
# vote_average('Under the Same Moon','5-7.5').
# vote_average('Under the Skin','5-7.5').
# vote_average('Under the Tuscan Sun','5-7.5').
# vote_average('Underclassman','5-7.5').
# vote_average('Undercover Brother','5-7.5').
# vote_average('Underdogs','5-7.5').
# vote_average('Underworld','5-7.5').
# vote_average('Underworld: Awakening','5-7.5').
# vote_average('Underworld: Evolution','5-7.5').
# vote_average('Underworld: Rise of the Lycans','5-7.5').
# vote_average('Undiscovered','under_5').
# vote_average('Undisputed','5-7.5').
# vote_average('Unfaithful','5-7.5').
# vote_average('Unfinished Business','5-7.5').
# vote_average('Unforgiven','over7.5').
# vote_average('Unfriended','5-7.5').
# vote_average('United 93','5-7.5').
# vote_average('United Passions','under_5').
# vote_average('Universal Soldier: The Return','under_5').
# vote_average('Unknown','5-7.5').
# vote_average('Unleashed','5-7.5').
# vote_average('Unnatural','under_5').
# vote_average('Unstoppable','5-7.5').
# vote_average('Unsullied','under_5').
# vote_average('Untraceable','5-7.5').
# vote_average('Up Close & Personal','5-7.5').
# vote_average('Up in the Air','5-7.5').
# vote_average('Up','over7.5').
# vote_average('Urban Legend','5-7.5').
# vote_average('Urban Legends: Final Cut','under_5').
# vote_average('Urbania','5-7.5').
# vote_average('V for Vendetta','over7.5').
# vote_average('Vaalu','5-7.5').
# vote_average('Vacation','5-7.5').
# vote_average('Valentine','5-7.5').
# vote_average('Valentines Day','5-7.5').
# vote_average('Valiant','5-7.5').
# vote_average('Valkyrie','5-7.5').
# vote_average('Valley of the Hearts Delight','5-7.5').
# vote_average('Valley of the Wolves: Iraq','under_5').
# vote_average('Vampire in Brooklyn','under_5').
# vote_average('Vampires Suck','under_5').
# vote_average('Vampires','5-7.5').
# vote_average('Vamps','under_5').
# vote_average('Vanilla Sky','5-7.5').
# vote_average('Vanity Fair','5-7.5').
# vote_average('Vantage Point','5-7.5').
# vote_average('Varsity Blues','5-7.5').
# vote_average('Veer-Zaara','5-7.5').
# vote_average('VeggieTales: The Pirates Who Dont Do Anything','5-7.5').
# vote_average('Velvet Goldmine','5-7.5').
# vote_average('Vera Drake','5-7.5').
# vote_average('Veronica Guerin','5-7.5').
# vote_average('Veronika Decides to Die','5-7.5').
# vote_average('Vertical Limit','5-7.5').
# vote_average('Very Bad Things','5-7.5').
# vote_average('Vessel','5-7.5').
# vote_average('Vicky Cristina Barcelona','5-7.5').
# vote_average('Victor Frankenstein','5-7.5').
# vote_average('Videodrome','5-7.5').
# vote_average('Virgin Territory','under_5').
# vote_average('Virtuosity','5-7.5').
# vote_average('Volcano','5-7.5').
# vote_average('Volver','5-7.5').
# vote_average('W.','5-7.5').
# vote_average('WALL·E','over7.5').
# vote_average('Wag the Dog','5-7.5').
# vote_average('Wah-Wah','5-7.5').
# vote_average('Waiting for Guffman','5-7.5').
# vote_average('Waiting...','5-7.5').
# vote_average('Waitress','5-7.5').
# vote_average('Waking Ned','5-7.5').
# vote_average('Wal-Mart: The High Cost of Low Price','5-7.5').
# vote_average('Walk Hard: The Dewey Cox Story','5-7.5').
# vote_average('Walk the Line','5-7.5').
# vote_average('Walking Tall','5-7.5').
# vote_average('Walking With Dinosaurs','5-7.5').
# vote_average('Walking and Talking','5-7.5').
# vote_average('Wall Street','5-7.5').
# vote_average('Wall Street: Money Never Sleeps','5-7.5').
# vote_average('Walter','5-7.5').
# vote_average('Waltz with Bashir','over7.5').
# vote_average('Wanderlust','5-7.5').
# vote_average('Wanted','5-7.5').
# vote_average('War Horse','5-7.5').
# vote_average('War of the Worlds','5-7.5').
# vote_average('War','5-7.5').
# vote_average('War, Inc.','5-7.5').
# vote_average('WarGames','5-7.5').
# vote_average('Warcraft','5-7.5').
# vote_average('Warlock','5-7.5').
# vote_average('Warlock: The Armageddon','5-7.5').
# vote_average('Warm Bodies','5-7.5').
# vote_average('Warrior','over7.5').
# vote_average('Warriors of Virtue','under_5').
# vote_average('Wasabi','5-7.5').
# vote_average('Watchmen','5-7.5').
# vote_average('Water & Power','under_5').
# vote_average('Water for Elephants','5-7.5').
# vote_average('Water','5-7.5').
# vote_average('Waterloo','5-7.5').
# vote_average('Waterworld','5-7.5').
# vote_average('Waynes World','5-7.5').
# vote_average('We Are Marshall','5-7.5').
# vote_average('We Are Your Friends','5-7.5').
# vote_average('We Bought a Zoo','5-7.5').
# vote_average('We Have Your Husband','5-7.5').
# vote_average('We Need to Talk About Kevin','5-7.5').
# vote_average('We Own the Night','5-7.5').
# vote_average('We Were Soldiers','5-7.5').
# vote_average('Weekend','5-7.5').
# vote_average('Welcome Home Roscoe Jenkins','5-7.5').
# vote_average('Welcome to Collinwood','5-7.5').
# vote_average('Welcome to Mooseport','under_5').
# vote_average('Welcome to the Dollhouse','5-7.5').
# vote_average('Welcome to the Rileys','5-7.5').
# vote_average('Welcome to the Sticks','5-7.5').
# vote_average('Wendy and Lucy','5-7.5').
# vote_average('Were No Angels','5-7.5').
# vote_average('Were the Millers','5-7.5').
# vote_average('West Side Story','5-7.5').
# vote_average('Western Religion','under_5').
# vote_average('Whale Rider','5-7.5').
# vote_average('What Dreams May Come','5-7.5').
# vote_average('What Happens in Vegas','5-7.5').
# vote_average('What Just Happened','5-7.5').
# vote_average('What Lies Beneath','5-7.5').
# vote_average('What Planet Are You From?','5-7.5').
# vote_average('What Women Want','5-7.5').
# vote_average('What a Girl Wants','5-7.5').
# vote_average('What the #$*! Do We (K)now!?','5-7.5').
# vote_average('What to Expect When Youre Expecting','5-7.5').
# vote_average('Whatever It Takes','5-7.5').
# vote_average('Whatever Works','5-7.5').
# vote_average('Whats Eating Gilbert Grape','over7.5').
# vote_average('Whats Love Got to Do with It','5-7.5').
# vote_average('Whats Your Number?','5-7.5').
# vote_average('Whats the Worst That Could Happen?','5-7.5').
# vote_average('When Did You Last See Your Father?','5-7.5').
# vote_average('When Harry Met Sally...','5-7.5').
# vote_average('When a Stranger Calls','5-7.5').
# vote_average('When the Cats Away','5-7.5').
# vote_average('When the Game Stands Tall','5-7.5').
# vote_average('When the Lights Went Out','5-7.5').
# vote_average('Where the Heart Is','5-7.5').
# vote_average('Where the Truth Lies','5-7.5').
# vote_average('Where the Wild Things Are','5-7.5').
# vote_average('While Were Young','5-7.5').
# vote_average('Whip It','5-7.5').
# vote_average('Whiplash','over7.5').
# vote_average('Whipped','under_5').
# vote_average('White Chicks','5-7.5').
# vote_average('White Fang','5-7.5').
# vote_average('White House Down','5-7.5').
# vote_average('White Noise 2: The Light','5-7.5').
# vote_average('White Noise','5-7.5').
# vote_average('White Oleander','5-7.5').
# vote_average('White Squall','5-7.5').
# vote_average('Whiteout','5-7.5').
# vote_average('Who Killed the Electric Car?','5-7.5').
# vote_average('Whos Your Caddy?','under_5').
# vote_average('Why Did I Get Married Too?','5-7.5').
# vote_average('Why Did I Get Married?','5-7.5').
# vote_average('Why I Did (Not) Eat My Father','5-7.5').
# vote_average('Wicked Blood','5-7.5').
# vote_average('Wicker Park','5-7.5').
# vote_average('Wild Card','5-7.5').
# vote_average('Wild Grass','5-7.5').
# vote_average('Wild Hogs','5-7.5').
# vote_average('Wild Target','5-7.5').
# vote_average('Wild Things','5-7.5').
# vote_average('Wild Wild West','5-7.5').
# vote_average('Wild','5-7.5').
# vote_average('Willard','5-7.5').
# vote_average('Willy Wonka & the Chocolate Factory','5-7.5').
# vote_average('Wimbledon','5-7.5').
# vote_average('Win a Date with Tad Hamilton!','5-7.5').
# vote_average('Wind Walkers','over7.5').
# vote_average('Windsor Drive','under_5').
# vote_average('Windtalkers','5-7.5').
# vote_average('Wing Commander','under_5').
# vote_average('Winged Migration','5-7.5').
# vote_average('Winnie Mandela','5-7.5').
# vote_average('Winnie the Pooh','5-7.5').
# vote_average('Winter Passing','5-7.5').
# vote_average('Winter in Wartime','5-7.5').
# vote_average('Winters Bone','5-7.5').
# vote_average('Winters Tale','5-7.5').
# vote_average('Wish I Was Here','5-7.5').
# vote_average('Witchboard','5-7.5').
# vote_average('Without Limits','5-7.5').
# vote_average('Without Men','under_5').
# vote_average('Without a Paddle','5-7.5').
# vote_average('Witless Protection','under_5').
# vote_average('Witness','5-7.5').
# vote_average('Wolf','5-7.5').
# vote_average('Wolves','5-7.5').
# vote_average('Woman Thou Art Loosed','5-7.5').
# vote_average('Woman in Gold','5-7.5').
# vote_average('Woman on Top','5-7.5').
# vote_average('Womb','5-7.5').
# vote_average('Wonder Boys','5-7.5').
# vote_average('Wonderland','5-7.5').
# vote_average('Wont Back Down','5-7.5').
# vote_average('Woo','5-7.5').
# vote_average('Woodstock','5-7.5').
# vote_average('Wordplay','5-7.5').
# vote_average('World Trade Center','5-7.5').
# vote_average('World War Z','5-7.5').
# vote_average('Worlds Greatest Dad','5-7.5').
# vote_average('Wrath of the Titans','5-7.5').
# vote_average('Wreck-It Ralph','5-7.5').
# vote_average('Wristcutters: A Love Story','5-7.5').
# vote_average('Wrong Turn','5-7.5').
# vote_average('Wuthering Heights','5-7.5').
# vote_average('Wyatt Earp','5-7.5').
# vote_average('X-Men Origins: Wolverine','5-7.5').
# vote_average('X-Men','5-7.5').
# vote_average('X-Men: Apocalypse','5-7.5').
# vote_average('X-Men: Days of Future Past','over7.5').
# vote_average('X-Men: First Class','5-7.5').
# vote_average('X-Men: The Last Stand','5-7.5').
# vote_average('X2','5-7.5').
# vote_average('Y Tu Mamá También','5-7.5').
# vote_average('Year One','under_5').
# vote_average('Yeh Jawaani Hai Deewani','5-7.5').
# vote_average('Yentl','5-7.5').
# vote_average('Yes Man','5-7.5').
# vote_average('Yes','5-7.5').
# vote_average('Yesterday Was a Lie','5-7.5').
# vote_average('Yoga Hosers','under_5').
# vote_average('Yogi Bear','5-7.5').
# vote_average('You Again','5-7.5').
# vote_average('You Can Count on Me','5-7.5').
# vote_average('You Cant Take It With You','5-7.5').
# vote_average('You Dont Mess with the Zohan','5-7.5').
# vote_average('You Got Served','under_5').
# vote_average('You Kill Me','5-7.5').
# vote_average('You Only Live Twice','5-7.5').
# vote_average('You Will Meet a Tall Dark Stranger','5-7.5').
# vote_average('You, Me and Dupree','5-7.5').
# vote_average('Young Adult','5-7.5').
# vote_average('Young Frankenstein','over7.5').
# vote_average('Young Guns','5-7.5').
# vote_average('Young Sherlock Holmes','5-7.5').
# vote_average('Your Highness','5-7.5').
# vote_average('Your Sisters Sister','5-7.5').
# vote_average('Yours, Mine and Ours','5-7.5').
# vote_average('Youth in Revolt','5-7.5').
# vote_average('Youve Got Mail','5-7.5').
# vote_average('Z Storm','5-7.5').
# vote_average('ZMD: Zombies of Mass Destruction','under_5').
# vote_average('Zack and Miri Make a Porno','5-7.5').
# vote_average('Zambezia','5-7.5').
# vote_average('Zathura: A Space Adventure','5-7.5').
# vote_average('Zero Dark Thirty','5-7.5').
# vote_average('Zero Effect','5-7.5').
# vote_average('Zipper','5-7.5').
# vote_average('Zodiac','5-7.5').
# vote_average('Zombie Hunter','under_5').
# vote_average('Zombieland','5-7.5').
# vote_average('Zookeeper','5-7.5').
# vote_average('Zoolander 2','under_5').
# vote_average('Zoolander','5-7.5').
# vote_average('Zoom','under_5').
# vote_average('Zulu','5-7.5').
# vote_average('[REC]','5-7.5').
# vote_average('[REC]²','5-7.5').
# vote_average('eXistenZ','5-7.5').
# vote_average('xXx','5-7.5').
# vote_average('xXx: State of the Union','under_5').
# vote_average('Æon Flux','5-7.5').

# %% [markdown]
# ![vote distribution.png](data:image/png;base64,...)

# %% [markdown]
# ![year distribution.png](data:image/png;base64,...)

# %% [markdown]
# ![duration distribution.png](data:image/png;base64,...)

# %% [markdown]
# ![popularity distribution.png](data:image/png;base64,...)

# %%
prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %%
prolog.retractall('genres_4(X,Y)')
prolog.retractall('genres_3(X,Y)')
prolog.retractall('genres_12(X,Y)')
prolog.retractall('common_director(X,Y)')
prolog.retractall('plot_keywords_3(X,Y)')
prolog.retractall('plot_keywords_12(X,Y)')
prolog.retractall('common_actors_3(X,Y)')
prolog.retractall('common_actors_2(X,Y)')
prolog.retractall('common_actors_1(X,Y)')
prolog.retractall('common_language(X,Y)')
prolog.retractall('same_color(X,Y)')
prolog.retractall('same_studio(X,Y)')
prolog.retractall('same_country(X,Y)')
prolog.retractall('same_decade(X,Y)')
prolog.assertz('(genres_4(X,Y) :-  genre(X,A), genre(Y,A), genre(X,B), genre(Y,B), genre(X,C), genre(Y,C), genre(X,D), genre(Y,D), A\=B, A\=C, A\=D, B\=C, B\=D, C\=D, X\=Y)') 
prolog.assertz('(genres_3(X,Y) :-  genre(X,A), genre(X,B), genre(X,C), genre(Y,A), genre(Y,B), genre(Y,C), X\=Y, A\= B, A\= C, B\=C, not(genres_4(X, Y)) )') 
prolog.assertz('(genres_12(X,Y) :-  genre(X,A), genre(Y,A), X\=Y, not(genres_3(X, Y)), not(genres_4(X, Y)) )')
prolog.assertz('(common_director(X,Y) :-  director(X,A), director(Y,A), X\=Y )')
prolog.assertz('(plot_keywords_3(X,Y) :-  keyword(X,A), keyword(Y,A), keyword(X,B), keyword(Y,B), keyword(X,C), keyword(Y,C),  A\=B, A\=C, B\=C, X\=Y)')
prolog.assertz('(plot_keywords_12(X,Y) :-  keyword(X,A), keyword(Y,A), X\=Y, not(plot_keywords_3(X,Y)) )')
prolog.assertz('(common_actors_3(X,Y) :-  actor(X,A), actor(X,B), actor(X,C), actor(Y,A), actor(Y,B), actor(Y,C), X\=Y, A \= B, A \= C, B \= C)')
prolog.assertz('(common_actors_2(X,Y) :-  actor(X,A), actor(X,B), actor(Y,A), actor(Y,B), X\=Y, A \= B, not(common_actors_3(X, Y)) )')
prolog.assertz('(common_actors_1(X,Y) :-  actor(X,A), actor(Y,A), X\=Y, not(common_actors_2(X, Y)), not(common_actors_3(X, Y)) )')
prolog.assertz('(common_language(X,Y) :- language(X,D), language(Y,D), X \= Y)')
prolog.assertz('(same_color(X,Y) :- color(X, C), color(Y, C), X \= Y )')
prolog.assertz('(same_studio(X,Y) :- studio(X, C), studio(Y, C), X \= Y )')
prolog.assertz('(same_country(X,Y) :- country(X, C), country(Y, C), X \= Y )')
prolog.assertz('(same_decade(X,Y) :- decade(X, C), decade(Y, C), X \= Y )')

# %%
queries = ["genres_4('","genres_3('","genres_12('","plot_keywords_3('", "plot_keywords_12('","common_actors_1('","common_actors_2('",
      "common_actors_3('","common_director('","common_language('", "same_color('", "same_studio('", "same_country('", "same_decade('"]
movie = "Avatar"
for q in queries: 
    res = prolog.query(q + movie +"',M)")
    print(len(list(res)))
# Out:
# 672
# 1260
# 2159
# 66
# 386
# 20
# 0
# 0
# 6
# 4101
# 0
# 311
# 4590
# 0

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
prolog.retractall('find_sim_5(X, Y)')
prolog.retractall('find_sim_4(X, Y)')
prolog.retractall('find_sim_3(X, Y)')
prolog.retractall('find_sim_2(X, Y)')
prolog.retractall('find_sim_1(X, Y)')
prolog.assertz('(find_sim_5(X,Y) :-  genres_4(X,Y),common_language(X,Y),plot_keywords_3(X,Y), common_director(X,Y) ) ')
prolog.assertz('(find_sim_4(X,Y) :-  genres_3(X,Y),common_language(X,Y),plot_keywords_3(X,Y) )')
prolog.assertz('(find_sim_3(X,Y) :-  genres_3(X,Y),common_language(X,Y),plot_keywords_12(X,Y) )')
prolog.assertz('(find_sim_2(X,Y) :-  genres_12(X,Y),common_language(X,Y),plot_keywords_12(X,Y) )')
prolog.assertz('(find_sim_1(X,Y) :-  genres_12(X,Y),common_language(X,Y), not(plot_keywords_12(X,Y)) )')
# The similarity of two movies is primarily dependent on their genre and plot. A common director can also play a part

# %%
movie = 'Avatar'
s = set()
q = prolog.query("find_sim_1('" + movie +"',M)")
for soln in q:
     m = soln['M']
     if m not in s:
          s.add(soln['M'])
q.close()
print(len(s))
# Out:
# 1203

# %%
# We use set structure to remove duplicates of the same find_sim_ query efficiently. Different find_sim_ queries do not produce
# duplicates based on how they are defined. So, we do not have to use set structure for simple_recommender as well
def recommend_movies(movie, similarity):
   s = set()
   ans = []
   q = prolog.query("find_sim_"+str(similarity)+"('" + movie +"',M)")
   for soln in q:
      m = soln['M']
      if m not in s:
         s.add(soln['M'])
         ans.append((soln["M"],similarity))
   return ans

def simple_recommender(movie):  
  rec = []
  rec.extend(recommend_movies(movie, 5))
  rec.extend(recommend_movies(movie, 4))
  rec.extend(recommend_movies(movie, 3))
  reclen = len(rec)
  reclen2 = int(0.3*reclen)
  reclen1 = int(0.2*reclen)
  temp = recommend_movies(movie, 2)
  if len(temp) >=reclen2:  
     rec.extend(temp[:reclen2])
  else :
    rec.extend(temp)
  temp = recommend_movies(movie, 1)
  if len(temp) >=reclen1:  
     rec.extend(temp[:reclen1])
  else :
    rec.extend(temp)
  return rec

# %%
simple_recommender("Avatar")
# Out:
# [('Pirates of the Caribbean: On Stranger Tides', 4),
#  ('John Carter', 4),
#  ('Predators', 4),
#  ('Star Trek Into Darkness', 4),
#  ('47 Ronin', 3),
#  ('Brave', 3),
#  ('Clash of the Titans', 3),
#  ('How to Train Your Dragon 2', 3),
#  ('Maleficent', 3),
#  ('The Hobbit: The Battle of the Five Armies', 3),
#  ('Thor', 3),
#  ('Thor: The Dark World', 3),
#  ('A Sound of Thunder', 3),
#  ('Ant-Man', 3),
#  ('Armageddon', 3),
#  ('Avengers: Age of Ultron', 3),
#  ('Babylon A.D.', 3),
#  ('Captain America: The Winter Soldier', 3),
#  ('Dune', 3),
#  ('Enders Game', 3),
#  ('G.I. Joe: Retaliation', 3),
#  ('Green Lantern', 3),
#  ('Guardians of the Galaxy', 3),
#  ('Independence Day', 3),
#  ('Iron Man 3', 3),
#  ('Journey 2: The Mysterious Island', 3),
#  ('Journey to the Center of the Earth', 3),
#  ('Jurassic World', 3),
#  ('Mad Max: Fury Road', 3),
#  ('Megaforce', 3),
#  ('Men in Black II', 3),
#  ('Men in Black', 3),
#  ('Moonraker', 3),
#  ('Oblivion', 3),
#  ('Pacific Rim', 3),
#  ('Planet of the Apes', 3),
#  ('Predator', 3),
#  ('Resident Evil: Afterlife', 3),
#  ('Star Trek', 3),
#  ('Starship Troopers', 3),
#  ('Steel', 3),
#  ('Terminator Genisys', 3),
#  ('The Empire Strikes Back', 3),
#  ('The Hunger Games: Catching Fire', 3),
#  ('The Hunger Games: Mockingjay - Part 2', 3),
#  ('The Matrix Reloaded', 3),
#  ('The Matrix Revolutions', 3),
#  ('The Time Machine', 3),
#  ('Titan A.E.', 3),
#  ('Total Recall', 3),
#  ('Transformers: Age of Extinction', 3),
#  ('Transformers: Dark of the Moon', 3),
#  ('Aliens vs Predator: Requiem', 3),
#  ('Mortal Kombat: Annihilation', 3),
#  ('Aliens in the Attic', 3),
#  ('Bill & Teds Bogus Journey', 3),
#  ('The Thief and the Cobbler', 3),
#  ('Treasure Planet', 3),
#  ('Zathura: A Space Adventure', 3),
#  ('300: Rise of an Empire', 2),
#  ('Abraham Lincoln: Vampire Hunter', 2),
#  ('Alien', 2),
#  ('Alien: Resurrection', 2),
#  ('Apocalypto', 2),
#  ('Attack the Block', 2),
#  ('Bait', 2),
#  ('Batman Begins', 2),
#  ('Batman: The Dark Knight Returns, Part 2', 2),
#  ('Battle: Los Angeles', 2),
#  ('Beowulf', 2),
#  ('Big Hero 6', 2),
#  ('Children of Men', 2),
#  ('Dawn of the Planet of the Apes', 2),
#  ('Doomsday', 2),
#  ('Dracula Untold', 2),
#  ('Dredd', 2),
#  ('10th & Wolf', 1),
#  ('16 Blocks', 1),
#  ('1941', 1),
#  ('2 Fast 2 Furious', 1),
#  ('21 Jump Street', 1),
#  ('22 Jump Street', 1),
#  ('3 Days to Kill', 1),
#  ('3 Ninjas Kick Back', 1),
#  ('3 Strikes', 1),
#  ('30 Minutes or Less', 1),
#  ('300', 1)]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 0.5: -0.75, 1: -0.5, 1.5: -0.25, 2:0, 2.5:0, 3:0, 3.5:0.25, 4:0.5, 4.5:0.75, 5:1}
score_weights = {1:0.1, 2:0.2, 3:0.3, 4:0.5, 5:1} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender
# the score weights favor similar movies of scale 4 or 5
def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie[0]] = rating_weights[rating] * score_weights[similar_movie[1]]
            else:
                movie_score[similar_movie[0]] += rating_weights[rating] * score_weights[similar_movie[1]] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# precision: 0.4697402597402597
# recall: 0.03333333333333334
# f1: 0.061356723014990996

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.6209185259185259
# recall: 0.07638888888888888
# f1: 0.1345144772426285

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 50)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
  
# We observe that by increasing the number of movies we use in the training the model tends to get more accurate by a small rate
# We can use up until 100 movies (no movies in the training set)
# The metrics result depend on the randomly chosen movies during training so they might fluctuate and not strictly increase for a bigger data set
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.579281968031968
# recall: 0.10416666666666667
# f1: 0.1750024893977067
